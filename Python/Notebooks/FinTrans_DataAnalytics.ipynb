# %%
s_orders = [
    220,
    316,
    345,
    251,
    350,
    195,
    191,
    203,
    255,
    194,
    234
]

z_orders = [
    250,
    398,
    247,
    203,
    212,
    272,
    244,
    267,
    349,
    260,
    273,
    265,
    235,
    182,
    310,
    239,
    192,
    267,
    279,
    224,
    185,
    161,
    251,
    249,
    234,
    238,
    110,
    211,
    158,
    166
]

sum1 = sum(s_orders)
sum2 = sum(z_orders)
print(f'{sum1} + {sum2} = {sum1+sum2}')
# Out:
# 2754 + 7131 = 9885
